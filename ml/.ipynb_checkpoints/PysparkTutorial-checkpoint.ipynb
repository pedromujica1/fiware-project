# %%
pip list
# Out:
# Package                     Version
# --------------------------- --------------
# appdirs                     1.4.4
# argon2-cffi                 21.1.0
# asttokens                   2.4.1
# attrs                       23.2.0
# Automat                     22.10.0
# Babel                       2.10.3
# bcc                         0.29.1
# bcrypt                      3.2.2
# beautifulsoup4              4.12.3
# bleach                      6.1.0
# blinker                     1.7.0
# boto3                       1.34.46
# botocore                    1.34.46
# Brlapi                      0.8.5
# Brotli                      1.1.0
# bytecode                    0.15.1
# certifi                     2023.11.17
# chardet                     5.2.0
# click                       8.1.6
# cloud-init                  24.4.1
# colorama                    0.4.6
# comm                        0.2.1
# command-not-found           0.3
# configobj                   5.0.8
# ...

# %%
# !which python
